# %% [markdown]
# <a href="https://colab.research.google.com/github/Somali19/18CSE119/blob/main/Assignment_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **ASSIGNMENT - 3**
#
# **NAME : SOMALI PATTJOSHI**
#
# **SECTION - B**
#
# **ROLL NUMBER : 18CSE119**
#
# **SUBJECT - DMDW LAB ***

# %% [markdown]
# Download a dataset from Kaggle and plot all the graphs and
# charts on the downloaded dataset..

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7529a26c-afc1-4451-a79b-99539fedf8be" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7529a26c-afc1-4451-a79b-99539fedf8be">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving heart_failure_clinical_records_dataset.csv to heart_failure_clinical_records_dataset (3).csv

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['heart_failure_clinical_records_dataset.csv']))  
df
# Out:
#       age  anaemia  creatinine_phosphokinase  ...  smoking  time  DEATH_EVENT
# 0    75.0        0                       582  ...        0     4            1
# 1    55.0        0                      7861  ...        0     6            1
# 2    65.0        0                       146  ...        1     7            1
# 3    50.0        1                       111  ...        0     7            1
# 4    65.0        1                       160  ...        0     8            1
# ..    ...      ...                       ...  ...      ...   ...          ...
# 294  62.0        0                        61  ...        1   270            0
# 295  55.0        0                      1820  ...        0   271            0
# 296  45.0        0                      2060  ...        0   278            0
# 297  45.0        0                      2413  ...        1   280            0
# 298  50.0        0                       196  ...        1   285            0
#
# [299 rows x 13 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=299, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
df.isnull().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %% [markdown]
# DATA VISUALIZATION

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Line Plot :

# %%
sns.set_theme(style="darkgrid")
f, ax = plt.subplots(figsize=(8.5, 6.5))
sns.lineplot(x="age", y="DEATH_EVENT", 
             data=df, color='black')
plt.xlabel('Age' )
plt.ylabel('DEATH_EVENT')
plt.title("DEATH_EVENT v/s Age")
plt.show()

# %%
sns.set_theme(style="darkgrid")
f, ax = plt.subplots(figsize=(8.5, 6.5))
sns.lineplot(x="ejection_fraction", y="DEATH_EVENT", 
             data=df ,color='red')
plt.xlabel('ejection_fraction' )
plt.ylabel('DEATH_EVENT')
plt.title("DEATH_EVENT v/s ejection_fraction")
plt.show()

# %%
sns.set_theme(style="darkgrid")
f, ax = plt.subplots(figsize=(8.5, 6.5))
sns.lineplot(x="creatinine_phosphokinase", y="DEATH_EVENT", 
             data=df , color='cyan')
plt.xlabel('creatinine_phosphokinasea' )
plt.ylabel('DEATH_EVENT')
plt.title("DEATH_EVENT v/s creatinine_phosphokinase")
plt.show()

# %%
sns.set_theme(style="darkgrid")
f, ax = plt.subplots(figsize=(8.5, 6.5))
sns.lineplot(x="platelets", y="DEATH_EVENT", 
             data=df)
plt.xlabel('platelets' )
plt.ylabel('DEATH_EVENT')
plt.title("DEATH_EVENT v/s platelets")
plt.show()

# %%
sns.set_theme(style="darkgrid")
f, ax = plt.subplots(figsize=(8.5, 6.5))
sns.lineplot(x="serum_creatinine", y="DEATH_EVENT", 
             data=df ,color='black')
plt.xlabel('serum_creatinine' )
plt.ylabel('DEATH_EVENT')
plt.title("DEATH_EVENT v/s serum_creatinine")
plt.show()

# %%
sns.set_theme(style="darkgrid")
f, ax = plt.subplots(figsize=(8.5, 6.5))
sns.lineplot(x="serum_sodium", y="DEATH_EVENT", 
             data=df , color='red')
plt.xlabel('serum_sodium' )
plt.ylabel('DEATH_EVENT')
plt.title("DEATH_EVENT v/s serum_sodium")
plt.show()

# %%
sns.set_theme(style="darkgrid")
f, ax = plt.subplots(figsize=(8.5, 6.5))
sns.lineplot(x="time", y="DEATH_EVENT", 
             data=df,color='skyblue')

plt.xlabel('Time' )
plt.ylabel('DEATH_EVENT')
plt.title("DEATH_EVENT v/s Time")
plt.show()

# %% [markdown]
# Scatter Plot :

# %%
sns.set_theme(style="darkgrid")
f, ax = plt.subplots(figsize=(8.5, 6.5))
sns.scatterplot(x="age", y="DEATH_EVENT",
                sizes=(1, 8), linewidth=0,
                data=df, ax=ax)
plt.title("DEATH_EVENT v/s Age")
# Out:
# Text(0.5, 1.0, 'DEATH_EVENT v/s Age')

# %%
sns.set_theme(style="darkgrid")
f, ax = plt.subplots(figsize=(8.5, 6.5))
sns.scatterplot(x="creatinine_phosphokinase", y="DEATH_EVENT",
                sizes=(1, 8), linewidth=0,
                data=df, ax=ax , color='yellow')
plt.title("DEATH_EVENT v/s creatinine_phosphokinase")
# Out:
# Text(0.5, 1.0, 'DEATH_EVENT v/s creatinine_phosphokinase')

# %%
sns.set_theme(style="darkgrid")
f, ax = plt.subplots(figsize=(8.5, 6.5))
sns.scatterplot(x="ejection_fraction", y="DEATH_EVENT",
                sizes=(1, 8), linewidth=0,
                data=df, ax=ax , color='purple')
plt.title("DEATH_EVENT v/s ejection_fraction")
# Out:
# Text(0.5, 1.0, 'DEATH_EVENT v/s ejection_fraction')

# %%
sns.set_theme(style="darkgrid")
f, ax = plt.subplots(figsize=(8.5, 6.5))
sns.scatterplot(x="platelets", y="DEATH_EVENT",
                sizes=(1, 8), linewidth=0,
                data=df, ax=ax)
plt.title("DEATH_EVENT v/s platelets")
# Out:
# Text(0.5, 1.0, 'DEATH_EVENT v/s platelets')

# %%
sns.set_theme(style="darkgrid")
f, ax = plt.subplots(figsize=(8.5, 6.5))
sns.scatterplot(x="serum_creatinine", y="DEATH_EVENT",
                sizes=(1, 8), linewidth=0,
                data=df, ax=ax, color='cyan')
plt.title("DEATH_EVENT v/s serum_creatinine")
# Out:
# Text(0.5, 1.0, 'DEATH_EVENT v/s serum_creatinine')

# %%
sns.set_theme(style="darkgrid")
f, ax = plt.subplots(figsize=(8.5, 6.5))
sns.scatterplot(x="serum_sodium", y="DEATH_EVENT",
                sizes=(1, 8), linewidth=0,
                data=df, ax=ax , color='r')
plt.title("DEATH_EVENT v/s serum_sodium")
# Out:
# Text(0.5, 1.0, 'DEATH_EVENT v/s serum_sodium')

# %%
sns.set_theme(style="darkgrid")
f, ax = plt.subplots(figsize=(8.5, 6.5))
sns.scatterplot(x="time", y="DEATH_EVENT",
                sizes=(1, 8), linewidth=0,
                data=df, ax=ax , color='g')
plt.title("DEATH_EVENT v/s time")
# Out:
# Text(0.5, 1.0, 'DEATH_EVENT v/s time')

# %% [markdown]
# Bar Plot

# %%
sns.set_theme(style="darkgrid")
f, ax = plt.subplots(figsize=(32, 12))
plt.title("DEATH_EVENT v/s age")
sns.barplot(x="age", y="DEATH_EVENT", data=df, color='hotpink')

# %%
sns.set_theme(style="darkgrid")
f, ax = plt.subplots(figsize=(10, 6))
plt.title("DEATH_EVENT v/s anaemia")
sns.barplot(x="anaemia", y="DEATH_EVENT", data=df, color='green')

# %%
sns.set_theme(style="darkgrid")
f, ax = plt.subplots(figsize=(12, 6))
plt.title("DEATH_EVENT v/s diabetes")
sns.barplot(x="diabetes", y="DEATH_EVENT", data=df, color='c')

# %%
sns.set_theme(style="darkgrid")
f, ax = plt.subplots(figsize=(12, 6))
plt.title("DEATH_EVENT v/s high_blood_pressure")
sns.barplot(x="high_blood_pressure", y="DEATH_EVENT", data=df, color='r')

# %%
sns.set_theme(style="darkgrid")
f, ax = plt.subplots(figsize=(12, 6))
plt.title("DEATH_EVENT v/s sex")
sns.barplot(x="sex", y="DEATH_EVENT", data=df, color='g')

# %% [markdown]
# Histogram

# %%
sns.set_theme(style="darkgrid")
f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)
sns.histplot(
    df,
    x="age", hue="DEATH_EVENT",
    palette="light:red",
    edgecolor=".3",
    linewidth=.5
    
)
plt.title("DEATH_EVENT v/s Age")
# Out:
# Text(0.5, 1.0, 'DEATH_EVENT v/s Age')

# %%
sns.set_theme(style="darkgrid")
f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)
sns.histplot(
    df,
    x="anaemia", hue="DEATH_EVENT",
    palette="light:cyan",
    edgecolor=".3",
    linewidth=.5
    
)
plt.title("DEATH_EVENT v/s anaemia")
# Out:
# Text(0.5, 1.0, 'DEATH_EVENT v/s anaemia')

# %%
sns.set_theme(style="darkgrid")
f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)
sns.histplot(
    df,
    x="diabetes", hue="DEATH_EVENT",
    palette="light:blue",
    edgecolor=".3",
    linewidth=.5
    
)
plt.title("DEATH_EVENT v/s diabetes")
# Out:
# Text(0.5, 1.0, 'DEATH_EVENT v/s diabetes')

# %%
sns.set_theme(style="darkgrid")
f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)
sns.histplot(
    df,
    x="sex", hue="DEATH_EVENT",
    palette="light:green",
    edgecolor=".3",
    linewidth=.5
    
)
plt.title("DEATH_EVENT v/s Gender")
# Out:
# Text(0.5, 1.0, 'DEATH_EVENT v/s Gender')

# %%
sns.set_theme(style="darkgrid")
f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)
sns.histplot(
    df,
    x="smoking", hue="DEATH_EVENT",
    palette="light:cyan",
    edgecolor=".3",
    linewidth=.5,
    color='red'
    
)
plt.title("DEATH_EVENT v/s smoking")
# Out:
# Text(0.5, 1.0, 'DEATH_EVENT v/s smoking')

# %%
sns.set_theme(style="darkgrid")
f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)
sns.histplot(
    df,
    x="time", hue="DEATH_EVENT",
    palette="light:red",
    edgecolor=".3",
    linewidth=.5,
    color='red'
    
)
plt.title("DEATH_EVENT v/s time")
# Out:
# Text(0.5, 1.0, 'DEATH_EVENT v/s time')

# %% [markdown]
# Box Plot

# %%
sns.set_theme(style="ticks", palette="pastel")
sns.boxplot(x="ejection_fraction", y="time",
            hue="DEATH_EVENT", palette=["m", "g"],
            data=df)

# %%
sns.set_theme(style="ticks", palette="pastel")
sns.boxplot(x="DEATH_EVENT", y="time",
            hue="DEATH_EVENT", palette=["m", "g"],
            data=df)

# %%
sns.set_theme(style="ticks", palette="pastel")
sns.boxplot(x="DEATH_EVENT", y="smoking",
            hue="DEATH_EVENT", palette=["m", "g"],
            data=df)

# %%
sns.set_theme(style="ticks", palette="pastel")
sns.boxplot(x="DEATH_EVENT", y="anaemia",
            hue="DEATH_EVENT", palette=["m", "g"],
            data=df)

# %% [markdown]
# Pair Plot

# %%
sns.set_theme(style="ticks")
sns.pairplot(df, hue="DEATH_EVENT")

# %% [markdown]
# Heat Map

# %%
cor=df.corr()
plt.figure(figsize=(20,12))
sns.heatmap(cor,annot=True,cmap='coolwarm')
plt.show()
